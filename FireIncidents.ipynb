# %% [markdown]
# # Fire Incidents - Max Pietras

# %% [markdown]
# My dataset is fire incidents in Pittsburgh. It lists the type, neighborhood, time, zone, and address of all fire incidents from 2017 to August 2022. I want to look at the number of fire incidents in each neighborhood to determine which would be the safest by having the MOST fires compared to the overall population of the neighborhood. It may be a surprise to hear that the most fires make a neighborhood safer. The reason I do this is because the more past fire incidents, the more experience the area has with fighting fires and responding quickly. A neighborhood with only 20 fires since 2017 may not be as well prepared as a neighborhood with 200. I first use pd.read_csv() to read out the data.

# %%
import pandas as pd
fire = pd.read_csv("fireIncidents.csv")
fire
# Out:
#          call_no  incident_type                       type_description  \
# 0     F160029985          111.0                          Building fire
# 1     F180022058          111.0                          Building fire
# 2     F180022102          131.0                 Passenger vehicle fire
# 3     F170043431          131.0                 Passenger vehicle fire
# 4     F180021111          111.0                          Building fire
# ...          ...            ...                                    ...
# 8922  F220082010          130.0  Mobile property (vehicle) fire, Other
# 8923  F220082038          113.0    Cooking fire, confined to container
# 8924  F220082248          111.0                          Building fire
# 8925  F220082275          142.0  Brush or brush-and-grass mixture fire
# 8926  F220082351          113.0    Cooking fire, confined to container
#
#                                              address           alarm_time  \
# 0          800 BLOCK CENTER ST, WILKINSBURG PA 15221  2016-04-21T05:01:04
# 1           1100 BLOCK JANE ST, WILKINSBURG PA 15221  2018-03-13T08:34:43
# 2     SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212  2018-03-13T11:54:23
# 3         1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212  2017-05-31T08:39:47
# 4         2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205  2018-03-09T10:26:42
# ...                                              ...                  ...
# 8922  4400 BLOCK BROWNS HILL RD, PITTSBURGH PA 15218  2022-11-03T17:46:47
# 8923       600 BLOCK HOLLACE ST, PITTSBURGH PA 15211  2022-11-03T19:13:44
# 8924    2400 BLOCK WATERMAN AVE, PITTSBURGH PA 15227  2022-11-04T12:35:38
# 8925        100 BLOCK REDLYN ST, PITTSBURGH PA 15223  2022-11-04T14:22:12
# 8926        700 BLOCK MERCER ST, PITTSBURGH PA 15219  2022-11-04T18:22:26
#
#       alarms primary_unit  census_tract neighborhood  council_district  ward  \
# 0          1      231EN16           NaN          NaN               NaN   NaN
# 1          1      231EN16           NaN          NaN               NaN   NaN
# 2          0      231EN32        2406.0          NaN               NaN   NaN
# 3          0      231EN38        2509.0     Fineview               6.0  25.0
# 4          1      231EN31        2808.0    Fairywood               2.0  28.0
# ...      ...          ...           ...          ...               ...   ...
# 8922       0      231EN19        1517.0          NaN               NaN   NaN
# 8923       1      231EN10         501.0  Middle Hill               6.0   5.0
# 8924       1      231EN23        2904.0          NaN               NaN   NaN
# 8925       0      231EN23        3001.0    Knoxville               3.0  30.0
# 8926       1      231EN04         305.0          NaN               NaN   NaN
#
#              tract  public_works_division  pli_division  police_zone  \
# 0     4.200356e+10                    NaN           NaN          NaN
# 1     4.200356e+10                    NaN           NaN          NaN
# 2              NaN                    NaN           NaN          NaN
# 3     4.200325e+10                    1.0          25.0          1.0
# 4     4.200356e+10                    5.0          28.0          6.0
# ...            ...                    ...           ...          ...
# 8922           NaN                    NaN           NaN          NaN
# 8923  4.200305e+10                    3.0           5.0          2.0
# 8924           NaN                    NaN           NaN          NaN
# 8925  4.200330e+10                    5.0          30.0          3.0
# 8926           NaN                    NaN           NaN          NaN
#
#      fire_zone   latitude  longitude
# 0         3-16  40.441275 -79.882485
# 1         3-21  40.436342 -79.881003
# 2         1-1A        NaN        NaN
# 3         1-10  40.460303 -80.006980
# 4         1-16  40.449009 -80.076607
# ...        ...        ...        ...
# 8922      2-12        NaN        NaN
# 8923       2-5  40.449953 -79.967408
# 8924      4-15        NaN        NaN
# 8925       4-7  40.413520 -79.991463
# 8926       2-1        NaN        NaN
#
# [8927 rows x 18 columns]

# %% [markdown]
# Here we can see there is a lot of information we don't need. By only looking at the number of fire incidents, I really only need one column, neighborhoods. I show neighborhoods and incident type because later I will see the distribution of the types of fires.

# %%
data = pd.read_csv("fireIncidents.csv", index_col="neighborhood", parse_dates=True)
del data["police_zone"]
del data["call_no"]
del data["address"]
del data["alarm_time"]
del data["alarms"]
del data["primary_unit"]
del data["census_tract"]
del data["ward"]
del data["council_district"]
del data["tract"]
del data["public_works_division"]
del data["pli_division"]
del data["fire_zone"]
del data["latitude"]
del data["longitude"]
del data["incident_type"]
data
# Out:
#                                    type_description
# neighborhood
# NaN                                   Building fire
# NaN                                   Building fire
# NaN                          Passenger vehicle fire
# Fineview                     Passenger vehicle fire
# Fairywood                             Building fire
# ...                                             ...
# NaN           Mobile property (vehicle) fire, Other
# Middle Hill     Cooking fire, confined to container
# NaN                                   Building fire
# Knoxville     Brush or brush-and-grass mixture fire
# NaN             Cooking fire, confined to container
#
# [8927 rows x 1 columns]

# %% [markdown]
# This looks much better and we now see only the neighborhoods and their incident type. "NaN" will pop up as the listed neighborhood multiple times. There is not much we can do about that so I will be ignoring any data with "NaN" as the neighborhood.

# %%
data3 = data['type_description'].value_counts()
data3.plot.bar(figsize = (20,10))

# %% [markdown]
# Here I am checking whether or not I should weigh the types of fires as well as their prevalance in each neighborhood. I came to the conclusion that since 26 of the types of fire incidents have less than 100 occurences, I will just be looking at the total amount of fire incidents in each neighborhood.

# %% [markdown]
#  _____________________________________________________________________________________

# %% [markdown]
# Looking at the total number of fire incidents in each neighborhood using .value_counts(), I see that Carrick, the Central Business District, Squirrel Hill South, South Side Flats, and Hazelwood have had the most fire incidents in the past 5 years. St. Clair, East Carnegie, Mt. Oliver, Regent Square, and Mount Oliver Borough have had the least incidents. I will then plot a bar graph displaying the total number of fires in all neighborhoods.

# %%
data2 = fire['neighborhood'].value_counts()
data2
# Out:
# Carrick                      275
# Central Business District    247
# Squirrel Hill South          242
# South Side Flats             239
# Hazelwood                    230
#                             ...
# St. Clair                     11
# East Carnegie                 11
# Mt. Oliver                    11
# Regent Square                  8
# Mount Oliver Borough           6
# Name: neighborhood, Length: 91, dtype: int64

# %%
data2.plot.barh(figsize = (18,40))

# %% [markdown]
# We cannot determine the best neighborhood for fire safety on this data alone. Some neighborhoods are much larger than others, and naturally there will be more fires in bigger neighborhoods with more people and buildings. To figure out which neighboorhood is the best for fire safety, we need to look at the total number of fire incidents compared to the total population.

# %%
pop = pd.read_csv("population2.csv")

# %% [markdown]
# Here is a population dataset that I trim down to just the neighborhood and its population in 2020. I will use these numbers combined with fire incidents to determine the safest neighborhood regarding fires.

# %%
pop2 = pop[["Neighborhood", "2020_Total_Population"]]

pop2
# Out:
#                                 Neighborhood  2020_Total_Population
# 0                           Allegheny Center                   1419
# 1                             Allegheny West                    540
# 2                                  Allentown                   2305
# 3   Arlington - Arlington Heights (Combined)                   2040
# 4                                 Banksville                   4127
# ..                                       ...                    ...
# 84                       Upper Lawrenceville                   2394
# 85                                  West End                    205
# 86                              West Oakland                   2534
# 87                                  Westwood                   3332
# 88                                   Windgap                   1344
#
# [89 rows x 2 columns]

# %% [markdown]
# After putting everything into a dataset and dividing fires by population, I multiply the average by 100 for the purpose of readability. I trim the dataset down to only look at the neighborhoods and their average x 100.

# %%
div = pd.read_csv("population2.csv")
div
# Out:
#            Neighborhood  Fires  Population   Average  Average x 100
# 0      Allegheny Center     60        1419  0.042283       4.228330
# 1        Allegheny West     42         540  0.077778       7.777778
# 2             Allentown    120        2305  0.052061       5.206074
# 3             Arlington     47        2040  0.023039       2.303922
# 4            Banksville     57        4127  0.013811       1.381149
# ..                  ...    ...         ...       ...            ...
# 84  Upper Lawrenceville     49        2394  0.020468       2.046784
# 85             West End     20         205  0.097561       9.756098
# 86         West Oakland     58        2534  0.022889       2.288871
# 87             Westwood     25        3332  0.007503       0.750300
# 88              Windgap     19         134  0.141791      14.179104
#
# [89 rows x 5 columns]

# %%
df2 = div[['Neighborhood', 'Average x 100']]
df2
# Out:
#            Neighborhood  Average x 100
# 0      Allegheny Center       4.228330
# 1        Allegheny West       7.777778
# 2             Allentown       5.206074
# 3             Arlington       2.303922
# 4            Banksville       1.381149
# ..                  ...            ...
# 84  Upper Lawrenceville       2.046784
# 85             West End       9.756098
# 86         West Oakland       2.288871
# 87             Westwood       0.750300
# 88              Windgap      14.179104
#
# [89 rows x 2 columns]

# %% [markdown]
# Before plotting I sort the values so the graph goes in order.

# %%
df3= df2.sort_values('Average x 100',ascending=False)
df3
# Out:
#            Neighborhood  Average x 100
# 69          South Shore      79.310345
# 55          North Shore      19.601329
# 88              Windgap      14.179104
# 85             West End       9.756098
# 41        Homewood West       8.722741
# ..                  ...            ...
# 66            Shadyside       1.077234
# 74  Squirrel Hill North       1.035441
# 50          Morningside       0.984010
# 64        Regent Square       0.823893
# 87             Westwood       0.750300
#
# [89 rows x 2 columns]

# %% [markdown]
# As we can see, the top 5 neighborhoods with the highest fire to population ratio are Chateau, South Shore, North Shore, Windgap, and West End.

# %%
df3.plot.barh(x = "Neighborhood", y = "Average x 100", figsize = (15,20))

# %% [markdown]
# # Conclusion
#
# Based on the data, I have determined that South Shore is the best neighborhood. It has the highest ratio, and with that it is the most prepared to stop fires. The entire neighborhood also borders water on one side adding to the comfort that South Shore is safe regarding fires.
